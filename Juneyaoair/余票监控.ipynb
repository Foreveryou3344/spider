# %%
import requests
import json
szm = {"丽江":"LJG",
       "惠州":"HUZ",
       "南京":"NKG",
       "襄阳":"XFN",
       "宜昌":"YIH",
       "西安":"XIY","深圳":"SZX","三亚":"SYX","上海":"SHA","昆明":"KMG","哈尔滨":"HRB","重庆":"CKG","广州":"CAN","成都":"CTU"}
careinfo={
    'departureDate':"2020-09-11",
    "returnDate":"2020-10-13",
    "sendCode":'上海',
    "arrCode":'广州',
    'flightNo':[]
}
url = 'http://homobile.juneyaoair.com:86/v2/flight/AvFare'
data = {"sendCode":szm[careinfo['sendCode']],
        "arrCode":szm[careinfo['arrCode']],
        "returnDate":careinfo['returnDate'],
        "departureDate": careinfo['departureDate'],
        "loginKeyInfo":"",
        "directType":"D",
        "platformInfo":"ios",
        "channelCode":"MOBILE",
        "sign":"c629e4364ab6536d70f224e24da67ece",
        "flightType":"OW",
        "ffpId":"",
        "ffpCardNo":"",
        "tripType":"D",
        "blackBox":"eyJ0b2tlbklkIjoiR0plS0hKRVlQRjBublllb0hIV3VqQUxwRFFzd1hqcXpibVwvcXBiSmhuOUNOMW9KS3F4NG1pbVpCUzRSYlZlV1k0M2V3ZkwzMHc5eldTOTF2dVFKb21RPT0iLCJvcyI6ImlPUyIsInNlcUlkIjoiMTU5ODU3OTcyODUyODU2ODk1NyIsInByb2ZpbGVUaW1lIjo0ODUsInZlcnNpb24iOiIzLjYuMiJ9",
        "clientVersion":"6.1.0"}
headers = {
    'Host':'homobile.juneyaoair.com:86',
    'platformInfo':'ios',
    'Accept':'*/*',
    'Connection':'keep-alive',
    'Accept-Language':'zh-cn',
    'clientVersion':'6.1.0',
    'token':'www.juneyaoair.com',
    'channelCode':'MOBILE',
    'versionCode':'61000',
    'Accept-Encoding':'gzip, deflate',
    'User-Agent':'JuneYaoAir/61000 CFNetwork/1128.0.1 Darwin/19.6.0',
    'Connection':'keep-alive',
    'Content-Type':'application/json'
}
s = json.dumps(data)
r = requests.post(url=url,headers=headers,data=s)
json = json.loads(r.text)
flightInfoList = json['flightInfoList']
# print(json)
for flightInfo in flightInfoList:
#     print(flightInfo)
    if (flightInfo['flightNo'] in careinfo['flightNo']) or len(careinfo['flightNo'])==0:
#         print(flightInfo)
        for cabinFare in flightInfo['cabinFareList']:
#             print(cabinFare)
            if cabinFare['cabinCode']=='X':
                print(u'您所监控的航班:%s (%s%s-%s%s)'%(flightInfo['flightNo'],flightInfo['depCityName'],flightInfo['depAirportName'],flightInfo['arrCityName'],flightInfo['arrAirportName']))
                print(u'起飞时间:'+flightInfo['depDateTime'])
                print(u'到达时间:'+flightInfo['arrDateTime'])
                if cabinFare['cabinNumber']=='A':
                    print(u'畅飞卡可兑换客舱出现了！')
                elif cabinFare['cabinNumber']=='0':
                    print(u'畅飞卡可兑换客舱已兑完！')
                elif int(cabinFare['cabinNumber']) > 0:
                    print(u'畅飞卡可兑换客舱还剩'+cabinFare['cabinNumber']+u'张！')
8"],["BTS","布拉迪斯拉发","BRATISLAVA","BULADISILAFA","BLDSLF","B","I","斯洛伐克","+1"],["LON","伦敦","LONDON","LUNDUN","LD","L","I","英国","0"],["LZO","泸州","LUZHOU","LUZHOU","LZ","L","D","中国","+8"],["LPF","六盘水","LIUPANSHUI","LIUPANSHUI","LPS","L","D","中国","+8"],["TLQ","吐鲁番","TULUFAN","TULUFAN","TLF","T","D","中国","+8"],["SGZ","宋卡","SONGKHLA","SONGKA","SK","S","I","泰国","+7"],["BKI","沙巴","NEGERI SABAH","SHABA","SB","S","I","马来西亚","+8"],["TLS","图卢兹","TOULOUSE","TULUZI","TLZ","T","I","法国","+1"],["SWA","揭阳","JIEYANG","JIEYANG","JY","J","D","中国","+8"],["HIN","泗川","SACHEON SI","SICHUAN","SICHUAN","S","I","韩国","+9"],["RGN","仰光","YANGON","YANGGUANG","YG","Y","I","缅甸","+6"],["HKD","函馆","HAKODATE","HANGUAN","HG","H","I","日本","+9"],["PNH","金边","PHNOM PENH","JINBIAN","JB","J","I","柬埔寨","+7"],["YNT","烟台","YANTAI","YANTAI","YT","Y","D","中国","+8"],["TNA","济南","JINAN","JINAN","JN","J","D","中国","+8"],["YTY","扬州","YANGZHOU","YANGZHOU","YZ","Y","D","中国","+8"]]
print(allcity)
# Out:
# [['DYG', '张家界', 'ZHANGJIAJIE', 'ZHANGJIAJIE', 'ZJJ', 'Z', 'D', '中国', '+8'], ['ZHY', '中卫', 'ZHONGWEI', 'ZHONGWEI', 'ZW', 'Z', 'D', '中国', '+8'], ['NGO', '名古屋', 'NAGOYA', 'MINGGUWU', 'MGW', 'M', 'I', '日本', '+9'], ['WUX', '无锡', 'WUXI', 'WUXI', 'WX', 'W', 'D', '中国', '+8'], ['SIN', '新加坡', 'SINGAPORE', 'XINJIAPOSHI', 'XINJIAPO', 'X', 'I', '新加坡', '+8'], ['IKT', '伊尔库茨克', 'IRKUTSK', 'YIERKUCIKE', 'YEKCK', 'Y', 'I', '俄罗斯', '+8'], ['BFJ', '毕节', 'BIJIE', 'BIJIE', 'BJ', 'B', 'D', '中国', '+8'], ['LJG', '丽江', 'LIJIANG', 'LIJIANG', 'LJ', 'L', 'D', '中国', '+8'], ['XNN', '西宁', 'XINING', 'XINING', 'XN', 'X', 'D', '中国', '+8'], ['HUZ', '惠州', 'HUIZHOU', 'HUIZHOU', 'HZ', 'H', 'D', '中国', '+8'], ['NKG', '南京', 'NANJING', 'NANJING', 'NJ', 'N', 'D', '中国', '+8'], ['KUH', '钏路', 'KUSHIRO', 'CHUANLU', 'CL', 'C', 'I', '日本', '+9'], ['UYN', '榆林', 'YULIN', 'YULIN', 'YL', 'Y', 'D', '中国', '+8'], ['NBS', '长白山', 'CHANGBAISHAN', 'CHANGBAISHAN', 'CBS', 'C', 'D', '中国', '+8'], ['JUH', '池州', 'CHIZHOU', 'CHIZHOU', 'CZ', 'C', 'D', '
# ...
